# %%
#!pip install scipy  pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv("epa-sea-level.csv")

# %%
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
feature = "Year"
response = "CSIRO Adjusted Sea Level"

x = df[feature]
y = df[response]

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)

# Create first line of best fit
res = linregress(x, y)
x_pred = pd.Series([i for i in range(1879, 2050)])
y_pred = res.slope * x_pred + res.intercept
ax.plot(x_pred, y_pred, "r")

mm_df = df.loc[df["Year"] >= 2000]
mm_x = mm_df[feature]
mm_y = mm_df[response]
mm_res = linregress(mm_x, mm_y)
mm_x_pred = pd.Series([i for i in range(2000, 2050)])
mm_y_pred = mm_res.slope * mm_x_pred + mm_res.intercept
ax.plot(mm_x_pred, mm_y_pred, "g")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspace/boilerplate-sea-level-predictor/epa-sea-level.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://freecodecam-boilerplate-no5kfh86fcz.ws-eu110.gitpod.io/workspace/boilerplate-sea-level-predictor/epa-sea-level.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ax.show()
#
# AttributeError: 'Axes' object has no attribute 'show'
